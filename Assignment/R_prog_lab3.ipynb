# %%
Name:Swaroop Naik Roll:23102A0001

# %%
x <- c(2, 3, 5, 7)
x
# Out:
# [1] 2 3 5 7

# %%
c(2,3,5,7) + c(-2,-3,-5,8)
# Out:
# [1]  0  0  0 15

# %%
c(2,3,5,7) + c(-2,-3,-5,8)
# Out:
# [1]  0  0  0 15

# %%
c(2,3,5,7) - c(-2,-3,-5,8)
# Out:
# [1]  4  6 10 -1

# %%
c(2,3,5,7) * c(-2,-3,-5,8)
# Out:
# [1]  -4  -9 -25  56

# %%
c(2,3,5,7) / c(-2,-3,-5,8)
# Out:
# [1] -1.000 -1.000 -1.000  0.875

# %%
2^3
2^0.5
2^-0.5

c(2,3,5,7)^2
c(2,3,5,7)^c(2,3)
# Out:
# [1] 8
# [1] 1.414214
# [1] 0.7071068
# [1]  4  9 25 49
# [1]   4  27  25 343

# %%
2 %/% 2
5 %/% 2
7 %/% 3

c(2,3,5,7) %/% 2
c(2,3,5,7) %/% c(2,3)
# Out:
# [1] 1
# [1] 2
# [1] 2
# [1] 1 1 2 3
# [1] 1 1 2 2

# %%
2 %% 2
3 %% 2
7 %% 3
7 %% 4

c(2,3,5,7) %% 2
c(2,3,5,7) %% c(2,3)
# Out:
# [1] 0
# [1] 1
# [1] 1
# [1] 3
# [1] 0 1 1 1
# [1] 0 0 1 1

# %%
max(1.2, 3.4, -7.8)
max(c(1.2, 3.4, -7.8))
# Out:
# [1] 3.4
# [1] 3.4

# %%
min(1.2, 3.4, -7.8)
min(c(1.2, 3.4, -7.8))
# Out:
# [1] -7.8
# [1] -7.8

# %%
mean(c(2,3,4))
# Out:
# [1] 3

# %%
abs(-4)
abs(c(-1,-2,-3,4,5))
# Out:
# [1] 4
# [1] 1 2 3 4 5

# %%
sqrt(4)
sqrt(c(4,9,16,25))
# Out:
# [1] 2
# [1] 2 3 4 5

# %%
sum(c(2,3,5,7))
# Out:
# [1] 17

# %%
prod(c(2,3,5,7))
# Out:
# [1] 210

# %%
round(1.23)
round(1.83)
floor(1.83)
ceiling(1.23)
# Out:
# [1] 1
# [1] 2
# [1] 1
# [1] 2

# %%
log(10)
log(exp(1))
log(c(10,100,1000))

log10(10)
log10(100)
log10(c(10,100,1000))
# Out:
# [1] 2.302585
# [1] 1
# [1] 2.302585 4.605170 6.907755
# [1] 1
# [1] 2
# [1] 1 2 3

# %%
exp(1)
exp(2)
# Out:
# [1] 2.718282
# [1] 7.389056

# %%
x1 <- c(1,2,3,4)
x1

x2 <- x1^2
x2
# Out:
# [1] 1 2 3 4
# [1]  1  4  9 16

# %%
x <- matrix(
  nrow = 4,
  ncol = 2,
  data = c(1,2,3,4,5,6,7,8)
)

x
# Out:
#      [,1] [,2]
# [1,] 1    5
# [2,] 2    6
# [3,] 3    7
# [4,] 4    8

# %%
x[3,2]

# 21. Row-wise matrix
y <- matrix(
  nrow = 4,
  ncol = 2,
  data = c(1,2,3,4,5,6,7,8),
  byrow = TRUE
)

y
# Out:
# [1] 7
#      [,1] [,2]
# [1,] 1    2
# [2,] 3    4
# [3,] 5    6
# [4,] 7    8

# %%
dim(x)
nrow(x)
ncol(x)
mode(x)
attributes(x)
# Out:
# [1] 4 2
# [1] 4
# [1] 2
# [1] "numeric"
# $dim
# [1] 4 2

# %%
is.matrix(x)
is.matrix(y)
# Out:
# [1] TRUE
# [1] TRUE
